# %% [markdown]
# # Multimodal Cyclic Translation Network (MCTN) Model - MOSI

# %%
# !git clone https://github.com/M-Jafarkhani/Multimodal-Emotion-Recognition

# %%
import gdown

file_id = "1szKIqO0t3Be_W91xvf6aYmsVVUa7wDHU"
destination = "mosi_raw.pkl"

gdown.download(
    f"https://drive.google.com/uc?id={file_id}", destination, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1szKIqO0t3Be_W91xvf6aYmsVVUa7wDHU
# From (redirected): https://drive.google.com/uc?id=1szKIqO0t3Be_W91xvf6aYmsVVUa7wDHU&confirm=t&uuid=cfce083d-e367-4fa2-9d1c-6235a535cd67
# To: /content/mosi_raw.pkl
# 100%|██████████| 357M/357M [00:01<00:00, 247MB/s]
# 'mosi_raw.pkl'

# %% [markdown]
# ## Importing Libraries

# %%
import sys
import torch
from torch import nn
import matplotlib.pyplot as plt

sys.path.append('/content/Multimodal-Emotion-Recognition/src')

# %% [markdown]
# ## Importing Helper Functions

# %%
from loader import get_dataloader
from unimodals.modules import MLP
from fusions.MCTN import Encoder, Decoder
from evaluation.complexity import all_in_one
from training.MCTN import train, test
from utils import get_default_device, save_results

# %% [markdown]
# ## Loading the Dataset

# %%
train_data, valid_data, test_data = get_dataloader('/content/mosi_raw.pkl')

# %%
device = get_default_device()
print(device)
# Out:
# cuda

# %% [markdown]
# ## Model Architecture

# %%
max_seq = 20
feature_dim = 300
hidden_dim = 32

encoder0 = Encoder(feature_dim, hidden_dim, n_layers=1, dropout=0.0).to(device)
decoder0 = Decoder(hidden_dim, feature_dim, n_layers=1, dropout=0.0).to(device)
encoder1 = Encoder(hidden_dim, hidden_dim, n_layers=1, dropout=0.0).to(device)
decoder1 = Decoder(hidden_dim, feature_dim, n_layers=1, dropout=0.0).to(device)

reg_encoder = nn.GRU(hidden_dim, 32).to(device)
head = MLP(32, 64, 1).to(device)

allmodules = [encoder0, decoder0, encoder1, decoder1, reg_encoder, head]

# %% [markdown]
# ## Training

# %%
OUTPUT_MODEL_FILE_NAME = 'MOSI_Multimodal_Cyclic_Translation_Network'

# %%
def trainprocess():
    global OUTPUT_MODEL_FILE_NAME

    train_losses, valid_losses = train(
        train_data,
        valid_data,
        encoder0,
        decoder0,
        encoder1,
        decoder1,
        reg_encoder,
        head,
        criterion_t0=nn.MSELoss(),
        criterion_c=nn.MSELoss(),
        criterion_t1=nn.MSELoss(),
        criterion_r=nn.L1Loss(),
        max_seq_len=20,
        mu_t0=0.01,
        mu_c=0.01,
        mu_t1=0.01,
        dropout_p=0.15,
        early_stop=False,
        patience_num=15,
        lr=1e-4,
        weight_decay=0.01,
        op_type=torch.optim.AdamW,
        epoch=200,
        model_save=f"/content/{OUTPUT_MODEL_FILE_NAME}.pt",
    )
    return train_losses, valid_losses

train_losses, valid_losses = all_in_one(trainprocess, allmodules)
# Out:
# Epoch [1/200]
# Train Loss: 3.0637 | Regression Loss: 1.3256 | Embedding Loss: 1.7380
# Valid MAE: 1.4229 | Valid Accuracy: 42.5234% | Valid Recall: 38.8060%
# Saving Best
#
# Epoch [2/200]
# Train Loss: 3.0513 | Regression Loss: 1.3258 | Embedding Loss: 1.7255
# Valid MAE: 1.4196 | Valid Accuracy: 42.5234% | Valid Recall: 38.8060%
# Saving Best
#
# Epoch [3/200]
# Train Loss: 3.0593 | Regression Loss: 1.3358 | Embedding Loss: 1.7235
# Valid MAE: 1.4185 | Valid Accuracy: 42.5234% | Valid Recall: 38.8060%
# Saving Best
#
# Epoch [4/200]
# Train Loss: 3.0432 | Regression Loss: 1.3255 | Embedding Loss: 1.7177
# Valid MAE: 1.4203 | Valid Accuracy: 42.5234% | Valid Recall: 38.8060%
#
# Epoch [5/200]
# Train Loss: 3.0183 | Regression Loss: 1.3012 | Embedding Loss: 1.7170
# Valid MAE: 1.4165 | Valid Accuracy: 57.4766% | Valid Recall: 61.1940%
# Saving Best
#
# Epoch [6/200]
# Train Loss: 3.0217 | Regression Loss: 1.3162 | Embedding Loss: 1.7056
# Valid MAE: 1.4180 | Valid Accuracy: 57.4766% | Valid Recall: 61.1940%
#
# Epoch [7/200]
# Train Loss: 3.0395 | Regression Loss: 1.3113 | Embedding Loss: 1.7282
# Valid MAE: 1.4178 | Valid Accuracy: 57.4766% | Valid Recall: 61.1940%
#
# Epoch [8/200]
# Train Loss: 3.0394 | Regression Loss: 1.3147 | Embedding Loss: 1.7247
# Valid MAE: 1.4192 | Valid Accuracy: 42.5234% | Valid Recall: 38.8060%
#
# Epoch [9/200]
# Train Loss: 3.0238 | Regression Loss: 1.3116 | Embedding Loss: 1.7122
# Valid MAE: 1.4184 | Valid Accuracy: 55.1402% | Valid Recall: 56.2189%
#
# Epoch [10/200]
# Train Loss: 3.0411 | Regression Loss: 1.3245 | Embedding Loss: 1.7166
# Valid MAE: 1.4192 | Valid Accuracy: 42.5234% | Valid Recall: 38.8060%
#
# Epoch [11/200]
# Train Loss: 3.0314 | Regression Loss: 1.3222 | Embedding Loss: 1.7092
# Valid MAE: 1.4183 | Valid Accuracy: 59.3458% | Valid Recall: 59.2040%
#
# Epoch [12/200]
# Train Loss: 3.0167 | Regression Loss: 1.3015 | Embedding Loss: 1.7152
# Valid MAE: 1.4170 | Valid Accuracy: 60.2804% | Valid Recall: 62.1891%
#
# Epoch [13/200]
# Train Loss: 3.0144 | Regression Loss: 1.2957 | Embedding Loss: 1.7186
# Valid MAE: 1.4189 | Valid Accuracy: 54.2056% | Valid Recall: 51.2438%
#
# Epoch [14/200]
# Train Loss: 2.9824 | Regression Loss: 1.2581 | Embedding Loss: 1.7242
# Valid MAE: 1.4121 | Valid Accuracy: 63.0841% | Valid Recall: 63.1841%
# Saving Best
#
# Epoch [15/200]
# Train Loss: 2.8930 | Regression Loss: 1.1822 | Embedding Loss: 1.7108
# Valid MAE: 1.4046 | Valid Accuracy: 65.8879% | Valid Recall: 64.6766%
# Saving Best
#
# Epoch [16/200]
# Train Loss: 2.8390 | Regression Loss: 1.1113 | Embedding Loss: 1.7278
# Valid MAE: 1.3922 | Valid Accuracy: 69.1589% | Valid Recall: 68.1592%
# Saving Best
#
# Epoch [17/200]
# Train Loss: 2.7723 | Regression Loss: 1.0690 | Embedding Loss: 1.7033
# Valid MAE: 1.3982 | Valid Accuracy: 68.2243% | Valid Recall: 66.6667%
#
# Epoch [18/200]
# Train Loss: 2.7079 | Regression Loss: 0.9955 | Embedding Loss: 1.7124
# Valid MAE: 1.3812 | Valid Accuracy: 72.8972% | Valid Recall: 72.1393%
# Saving Best
#
# Epoch [19/200]
# Train Loss: 2.7153 | Regression Loss: 1.0067 | Embedding Loss: 1.7087
# Valid MAE: 1.4011 | Valid Accuracy: 64.0187% | Valid Recall: 62.1891%
#
# Epoch [20/200]
# Train Loss: 2.6986 | Regression Loss: 0.9689 | Embedding Loss: 1.7297
# Valid MAE: 1.4213 | Valid Accuracy: 46.2617% | Valid Recall: 42.7861%
#
# Epoch [21/200]
# Train Loss: 2.6515 | Regression Loss: 0.9370 | Embedding Loss: 1.7145
# Valid MAE: 1.4132 | Valid Accuracy: 52.8037% | Valid Recall: 49.7512%
#
# Epoch [22/200]
# Train Loss: 2.6279 | Regression Loss: 0.9263 | Embedding Loss: 1.7016
# Valid MAE: 1.4119 | Valid Accuracy: 53.7383% | Valid Recall: 50.7463%
#
# Epoch [23/200]
# Train Loss: 2.6523 | Regression Loss: 0.9450 | Embedding Loss: 1.7073
# Valid MAE: 1.4082 | Valid Accuracy: 58.4112% | Valid Recall: 55.7214%
#
# Epoch [24/200]
# Train Loss: 2.6687 | Regression Loss: 0.9525 | Embedding Loss: 1.7162
# Valid MAE: 1.3948 | Valid Accuracy: 64.9533% | Valid Recall: 62.6866%
#
# Epoch [25/200]
# Train Loss: 2.6364 | Regression Loss: 0.9314 | Embedding Loss: 1.7050
# Valid MAE: 1.3896 | Valid Accuracy: 66.8224% | Valid Recall: 65.1741%
#
# Epoch [26/200]
# Train Loss: 2.6162 | Regression Loss: 0.9129 | Embedding Loss: 1.7033
# Valid MAE: 1.3954 | Valid Accuracy: 62.6168% | Valid Recall: 60.1990%
#
# Epoch [27/200]
# Train Loss: 2.6235 | Regression Loss: 0.9164 | Embedding Loss: 1.7071
# Valid MAE: 1.4096 | Valid Accuracy: 50.4673% | Valid Recall: 47.2637%
#
# Epoch [28/200]
# Train Loss: 2.6435 | Regression Loss: 0.9404 | Embedding Loss: 1.7031
# Valid MAE: 1.4047 | Valid Accuracy: 58.8785% | Valid Recall: 56.2189%
#
# Epoch [29/200]
# Train Loss: 2.5771 | Regression Loss: 0.8753 | Embedding Loss: 1.7018
# Valid MAE: 1.4127 | Valid Accuracy: 50.4673% | Valid Recall: 47.2637%
#
# Epoch [30/200]
# Train Loss: 2.5830 | Regression Loss: 0.8697 | Embedding Loss: 1.7133
# Valid MAE: 1.4110 | Valid Accuracy: 51.4019% | Valid Recall: 48.2587%
#
# Epoch [31/200]
# Train Loss: 2.5825 | Regression Loss: 0.8751 | Embedding Loss: 1.7074
# Valid MAE: 1.4208 | Valid Accuracy: 46.7290% | Valid Recall: 43.2836%
#
# Epoch [32/200]
# Train Loss: 2.5569 | Regression Loss: 0.8491 | Embedding Loss: 1.7078
# Valid MAE: 1.3968 | Valid Accuracy: 63.0841% | Valid Recall: 60.6965%
#
# Epoch [33/200]
# Train Loss: 2.5815 | Regression Loss: 0.8760 | Embedding Loss: 1.7054
# Valid MAE: 1.4123 | Valid Accuracy: 50.0000% | Valid Recall: 46.7662%
#
# Epoch [34/200]
# Train Loss: 2.5775 | Regression Loss: 0.8429 | Embedding Loss: 1.7346
# Valid MAE: 1.3998 | Valid Accuracy: 60.2804% | Valid Recall: 57.7114%
#
# Epoch [35/200]
# Train Loss: 2.5724 | Regression Loss: 0.8524 | Embedding Loss: 1.7200
# Valid MAE: 1.4020 | Valid Accuracy: 58.8785% | Valid Recall: 56.2189%
#
# Epoch [36/200]
# Train Loss: 2.5647 | Regression Loss: 0.8514 | Embedding Loss: 1.7133
# Valid MAE: 1.3971 | Valid Accuracy: 61.2150% | Valid Recall: 58.7065%
#
# Epoch [37/200]
# Train Loss: 2.5785 | Regression Loss: 0.8476 | Embedding Loss: 1.7309
# Valid MAE: 1.4157 | Valid Accuracy: 48.1308% | Valid Recall: 44.7761%
#
# Epoch [38/200]
# Train Loss: 2.5198 | Regression Loss: 0.8171 | Embedding Loss: 1.7028
# Valid MAE: 1.4117 | Valid Accuracy: 51.8692% | Valid Recall: 48.7562%
#
# Epoch [39/200]
# Train Loss: 2.5582 | Regression Loss: 0.8595 | Embedding Loss: 1.6987
# Valid MAE: 1.4220 | Valid Accuracy: 47.1963% | Valid Recall: 43.7811%
#
# Epoch [40/200]
# Train Loss: 2.5539 | Regression Loss: 0.8467 | Embedding Loss: 1.7072
# Valid MAE: 1.4000 | Valid Accuracy: 60.2804% | Valid Recall: 57.7114%
#
# Epoch [41/200]
# Train Loss: 2.5148 | Regression Loss: 0.8146 | Embedding Loss: 1.7002
# Valid MAE: 1.4067 | Valid Accuracy: 52.8037% | Valid Recall: 49.7512%
#
# Epoch [42/200]
# Train Loss: 2.5202 | Regression Loss: 0.8036 | Embedding Loss: 1.7166
# Valid MAE: 1.3994 | Valid Accuracy: 58.8785% | Valid Recall: 56.2189%
#
# Epoch [43/200]
# Train Loss: 2.5336 | Regression Loss: 0.8235 | Embedding Loss: 1.7102
# Valid MAE: 1.4049 | Valid Accuracy: 57.0093% | Valid Recall: 54.2289%
#
# Epoch [44/200]
# Train Loss: 2.5512 | Regression Loss: 0.8309 | Embedding Loss: 1.7203
# Valid MAE: 1.3944 | Valid Accuracy: 61.6822% | Valid Recall: 59.2040%
#
# Epoch [45/200]
# Train Loss: 2.5310 | Regression Loss: 0.8290 | Embedding Loss: 1.7020
# Valid MAE: 1.4026 | Valid Accuracy: 57.4766% | Valid Recall: 54.7264%
#
# Epoch [46/200]
# Train Loss: 2.5130 | Regression Loss: 0.8041 | Embedding Loss: 1.7089
# Valid MAE: 1.4034 | Valid Accuracy: 57.0093% | Valid Recall: 54.2289%
#
# Epoch [47/200]
# Train Loss: 2.5140 | Regression Loss: 0.8015 | Embedding Loss: 1.7125
# Valid MAE: 1.3900 | Valid Accuracy: 63.0841% | Valid Recall: 60.6965%
#
# Epoch [48/200]
# Train Loss: 2.5343 | Regression Loss: 0.8178 | Embedding Loss: 1.7166
# Valid MAE: 1.3996 | Valid Accuracy: 59.3458% | Valid Recall: 56.7164%
#
# Epoch [49/200]
# Train Loss: 2.5089 | Regression Loss: 0.8058 | Embedding Loss: 1.7032
# Valid MAE: 1.4041 | Valid Accuracy: 56.5421% | Valid Recall: 53.7313%
#
# Epoch [50/200]
# Train Loss: 2.5158 | Regression Loss: 0.8095 | Embedding Loss: 1.7062
# Valid MAE: 1.4054 | Valid Accuracy: 54.6729% | Valid Recall: 51.7413%
#
# Epoch [51/200]
# Train Loss: 2.4980 | Regression Loss: 0.7848 | Embedding Loss: 1.7132
# Valid MAE: 1.4023 | Valid Accuracy: 58.8785% | Valid Recall: 56.2189%
#
# Epoch [52/200]
# Train Loss: 2.5277 | Regression Loss: 0.8228 | Embedding Loss: 1.7049
# Valid MAE: 1.3971 | Valid Accuracy: 60.7477% | Valid Recall: 58.2090%
#
# Epoch [53/200]
# Train Loss: 2.4451 | Regression Loss: 0.7384 | Embedding Loss: 1.7067
# Valid MAE: 1.3895 | Valid Accuracy: 60.7477% | Valid Recall: 58.2090%
#
# Epoch [54/200]
# Train Loss: 2.4975 | Regression Loss: 0.7803 | Embedding Loss: 1.7171
# Valid MAE: 1.4111 | Valid Accuracy: 51.8692% | Valid Recall: 48.7562%
#
# Epoch [55/200]
# Train Loss: 2.4685 | Regression Loss: 0.7558 | Embedding Loss: 1.7127
# Valid MAE: 1.3935 | Valid Accuracy: 61.6822% | Valid Recall: 59.2040%
#
# Epoch [56/200]
# Train Loss: 2.4821 | Regression Loss: 0.7790 | Embedding Loss: 1.7032
# Valid MAE: 1.4025 | Valid Accuracy: 58.8785% | Valid Recall: 56.2189%
#
# Epoch [57/200]
# Train Loss: 2.4732 | Regression Loss: 0.7576 | Embedding Loss: 1.7156
# Valid MAE: 1.3959 | Valid Accuracy: 61.6822% | Valid Recall: 59.2040%
#
# Epoch [58/200]
# Train Loss: 2.4632 | Regression Loss: 0.7536 | Embedding Loss: 1.7096
# Valid MAE: 1.3976 | Valid Accuracy: 60.7477% | Valid Recall: 58.2090%
#
# Epoch [59/200]
# Train Loss: 2.4526 | Regression Loss: 0.7515 | Embedding Loss: 1.7012
# Valid MAE: 1.4020 | Valid Accuracy: 59.8131% | Valid Recall: 57.2139%
#
# Epoch [60/200]
# Train Loss: 2.4706 | Regression Loss: 0.7679 | Embedding Loss: 1.7027
# Valid MAE: 1.3901 | Valid Accuracy: 61.2150% | Valid Recall: 58.7065%
#
# Epoch [61/200]
# Train Loss: 2.4500 | Regression Loss: 0.7438 | Embedding Loss: 1.7062
# Valid MAE: 1.3921 | Valid Accuracy: 60.7477% | Valid Recall: 58.2090%
#
# Epoch [62/200]
# Train Loss: 2.4727 | Regression Loss: 0.7591 | Embedding Loss: 1.7135
# Valid MAE: 1.3981 | Valid Accuracy: 60.2804% | Valid Recall: 57.7114%
#
# Epoch [63/200]
# Train Loss: 2.4707 | Regression Loss: 0.7597 | Embedding Loss: 1.7110
# Valid MAE: 1.3908 | Valid Accuracy: 61.6822% | Valid Recall: 59.2040%
#
# Epoch [64/200]
# Train Loss: 2.4369 | Regression Loss: 0.7348 | Embedding Loss: 1.7021
# Valid MAE: 1.4018 | Valid Accuracy: 59.3458% | Valid Recall: 56.7164%
#
# Epoch [65/200]
# Train Loss: 2.4596 | Regression Loss: 0.7294 | Embedding Loss: 1.7302
# Valid MAE: 1.3924 | Valid Accuracy: 61.2150% | Valid Recall: 58.7065%
#
# Epoch [66/200]
# Train Loss: 2.4331 | Regression Loss: 0.7283 | Embedding Loss: 1.7047
# Valid MAE: 1.3927 | Valid Accuracy: 60.7477% | Valid Recall: 58.2090%
#
# Epoch [67/200]
# Train Loss: 2.4386 | Regression Loss: 0.7363 | Embedding Loss: 1.7023
# Valid MAE: 1.4040 | Valid Accuracy: 57.9439% | Valid Recall: 55.2239%
#
# Epoch [68/200]
# Train Loss: 2.4192 | Regression Loss: 0.7167 | Embedding Loss: 1.7025
# Valid MAE: 1.3918 | Valid Accuracy: 60.7477% | Valid Recall: 58.2090%
#
# Epoch [69/200]
# Train Loss: 2.4541 | Regression Loss: 0.7313 | Embedding Loss: 1.7228
# Valid MAE: 1.3921 | Valid Accuracy: 60.7477% | Valid Recall: 58.2090%
#
# Epoch [70/200]
# Train Loss: 2.4423 | Regression Loss: 0.7300 | Embedding Loss: 1.7124
# Valid MAE: 1.4109 | Valid Accuracy: 53.2710% | Valid Recall: 50.2488%
#
# Epoch [71/200]
# Train Loss: 2.4326 | Regression Loss: 0.7289 | Embedding Loss: 1.7037
# Valid MAE: 1.3954 | Valid Accuracy: 60.7477% | Valid Recall: 58.2090%
#
# Epoch [72/200]
# Train Loss: 2.4656 | Regression Loss: 0.7526 | Embedding Loss: 1.7130
# Valid MAE: 1.4069 | Valid Accuracy: 56.0748% | Valid Recall: 53.2338%
#
# Epoch [73/200]
# Train Loss: 2.4353 | Regression Loss: 0.7171 | Embedding Loss: 1.7181
# Valid MAE: 1.4023 | Valid Accuracy: 59.8131% | Valid Recall: 57.2139%
#
# Epoch [74/200]
# Train Loss: 2.4161 | Regression Loss: 0.7145 | Embedding Loss: 1.7016
# Valid MAE: 1.3996 | Valid Accuracy: 61.2150% | Valid Recall: 58.7065%
#
# Epoch [75/200]
# Train Loss: 2.4390 | Regression Loss: 0.7392 | Embedding Loss: 1.6997
# Valid MAE: 1.3884 | Valid Accuracy: 62.1495% | Valid Recall: 59.7015%
#
# Epoch [76/200]
# Train Loss: 2.4445 | Regression Loss: 0.7356 | Embedding Loss: 1.7089
# Valid MAE: 1.3985 | Valid Accuracy: 61.2150% | Valid Recall: 58.7065%
#
# Epoch [77/200]
# Train Loss: 2.4357 | Regression Loss: 0.7160 | Embedding Loss: 1.7197
# Valid MAE: 1.3995 | Valid Accuracy: 61.2150% | Valid Recall: 58.7065%
#
# Epoch [78/200]
# Train Loss: 2.4264 | Regression Loss: 0.7127 | Embedding Loss: 1.7137
# Valid MAE: 1.4056 | Valid Accuracy: 58.8785% | Valid Recall: 56.2189%
#
# Epoch [79/200]
# Train Loss: 2.4392 | Regression Loss: 0.7278 | Embedding Loss: 1.7115
# Valid MAE: 1.3888 | Valid Accuracy: 62.1495% | Valid Recall: 59.7015%
#
# Epoch [80/200]
# Train Loss: 2.4419 | Regression Loss: 0.7226 | Embedding Loss: 1.7193
# Valid MAE: 1.4044 | Valid Accuracy: 58.8785% | Valid Recall: 56.2189%
#
# Epoch [81/200]
# Train Loss: 2.4271 | Regression Loss: 0.7088 | Embedding Loss: 1.7182
# Valid MAE: 1.4045 | Valid Accuracy: 57.9439% | Valid Recall: 55.2239%
#
# Epoch [82/200]
# Train Loss: 2.4196 | Regression Loss: 0.7148 | Embedding Loss: 1.7048
# Valid MAE: 1.3900 | Valid Accuracy: 61.6822% | Valid Recall: 59.2040%
#
# Epoch [83/200]
# Train Loss: 2.4592 | Regression Loss: 0.7515 | Embedding Loss: 1.7077
# Valid MAE: 1.4019 | Valid Accuracy: 60.2804% | Valid Recall: 57.7114%
#
# Epoch [84/200]
# Train Loss: 2.4278 | Regression Loss: 0.7226 | Embedding Loss: 1.7053
# Valid MAE: 1.4018 | Valid Accuracy: 60.2804% | Valid Recall: 57.7114%
#
# Epoch [85/200]
# Train Loss: 2.4302 | Regression Loss: 0.7252 | Embedding Loss: 1.7050
# Valid MAE: 1.3902 | Valid Accuracy: 61.2150% | Valid Recall: 58.7065%
#
# Epoch [86/200]
# Train Loss: 2.4073 | Regression Loss: 0.7059 | Embedding Loss: 1.7013
# Valid MAE: 1.3909 | Valid Accuracy: 61.6822% | Valid Recall: 59.2040%
#
# Epoch [87/200]
# Train Loss: 2.4041 | Regression Loss: 0.7029 | Embedding Loss: 1.7012
# Valid MAE: 1.3940 | Valid Accuracy: 61.2150% | Valid Recall: 58.7065%
#
# Epoch [88/200]
# Train Loss: 2.3928 | Regression Loss: 0.6736 | Embedding Loss: 1.7191
# Valid MAE: 1.4043 | Valid Accuracy: 58.4112% | Valid Recall: 55.7214%
#
# Epoch [89/200]
# Train Loss: 2.3841 | Regression Loss: 0.6874 | Embedding Loss: 1.6967
# Valid MAE: 1.4000 | Valid Accuracy: 59.8131% | Valid Recall: 57.2139%
#
# Epoch [90/200]
# Train Loss: 2.3741 | Regression Loss: 0.6760 | Embedding Loss: 1.6981
# Valid MAE: 1.3931 | Valid Accuracy: 61.2150% | Valid Recall: 58.7065%
#
# Epoch [91/200]
# Train Loss: 2.3963 | Regression Loss: 0.6905 | Embedding Loss: 1.7057
# Valid MAE: 1.3856 | Valid Accuracy: 62.6168% | Valid Recall: 60.1990%
#
# Epoch [92/200]
# Train Loss: 2.4094 | Regression Loss: 0.6874 | Embedding Loss: 1.7221
# Valid MAE: 1.3927 | Valid Accuracy: 60.7477% | Valid Recall: 58.2090%
#
# Epoch [93/200]
# Train Loss: 2.4035 | Regression Loss: 0.6838 | Embedding Loss: 1.7196
# Valid MAE: 1.3882 | Valid Accuracy: 61.6822% | Valid Recall: 59.2040%
#
# Epoch [94/200]
# Train Loss: 2.3630 | Regression Loss: 0.6546 | Embedding Loss: 1.7085
# Valid MAE: 1.4008 | Valid Accuracy: 60.2804% | Valid Recall: 57.7114%
#
# Epoch [95/200]
# Train Loss: 2.3925 | Regression Loss: 0.6773 | Embedding Loss: 1.7152
# Valid MAE: 1.3875 | Valid Accuracy: 61.6822% | Valid Recall: 59.2040%
#
# Epoch [96/200]
# Train Loss: 2.3847 | Regression Loss: 0.6785 | Embedding Loss: 1.7061
# Valid MAE: 1.3947 | Valid Accuracy: 60.2804% | Valid Recall: 57.7114%
#
# Epoch [97/200]
# Train Loss: 2.3761 | Regression Loss: 0.6656 | Embedding Loss: 1.7105
# Valid MAE: 1.3860 | Valid Accuracy: 63.0841% | Valid Recall: 60.6965%
#
# Epoch [98/200]
# Train Loss: 2.4118 | Regression Loss: 0.6957 | Embedding Loss: 1.7161
# Valid MAE: 1.3928 | Valid Accuracy: 61.2150% | Valid Recall: 58.7065%
#
# Epoch [99/200]
# Train Loss: 2.3796 | Regression Loss: 0.6545 | Embedding Loss: 1.7251
# Valid MAE: 1.3833 | Valid Accuracy: 63.5514% | Valid Recall: 61.1940%
#
# Epoch [100/200]
# Train Loss: 2.3822 | Regression Loss: 0.6828 | Embedding Loss: 1.6994
# Valid MAE: 1.3940 | Valid Accuracy: 60.7477% | Valid Recall: 58.2090%
#
# Epoch [101/200]
# Train Loss: 2.3682 | Regression Loss: 0.6481 | Embedding Loss: 1.7201
# Valid MAE: 1.3930 | Valid Accuracy: 60.7477% | Valid Recall: 58.2090%
#
# Epoch [102/200]
# Train Loss: 2.3534 | Regression Loss: 0.6380 | Embedding Loss: 1.7154
# Valid MAE: 1.3875 | Valid Accuracy: 61.2150% | Valid Recall: 58.7065%
#
# Epoch [103/200]
# Train Loss: 2.3549 | Regression Loss: 0.6418 | Embedding Loss: 1.7131
# Valid MAE: 1.3976 | Valid Accuracy: 61.2150% | Valid Recall: 58.7065%
#
# Epoch [104/200]
# Train Loss: 2.3820 | Regression Loss: 0.6789 | Embedding Loss: 1.7031
# Valid MAE: 1.3860 | Valid Accuracy: 62.6168% | Valid Recall: 60.1990%
#
# Epoch [105/200]
# Train Loss: 2.3184 | Regression Loss: 0.6177 | Embedding Loss: 1.7007
# Valid MAE: 1.3871 | Valid Accuracy: 62.6168% | Valid Recall: 60.1990%
#
# Epoch [106/200]
# Train Loss: 2.3375 | Regression Loss: 0.6308 | Embedding Loss: 1.7067
# Valid MAE: 1.3893 | Valid Accuracy: 61.2150% | Valid Recall: 58.7065%
#
# Epoch [107/200]
# Train Loss: 2.3838 | Regression Loss: 0.6704 | Embedding Loss: 1.7135
# Valid MAE: 1.3904 | Valid Accuracy: 60.7477% | Valid Recall: 58.2090%
#
# Epoch [108/200]
# Train Loss: 2.3284 | Regression Loss: 0.6224 | Embedding Loss: 1.7060
# Valid MAE: 1.3852 | Valid Accuracy: 62.1495% | Valid Recall: 59.7015%
#
# Epoch [109/200]
# Train Loss: 2.3723 | Regression Loss: 0.6667 | Embedding Loss: 1.7057
# Valid MAE: 1.3845 | Valid Accuracy: 62.6168% | Valid Recall: 60.1990%
#
# Epoch [110/200]
# Train Loss: 2.3957 | Regression Loss: 0.6899 | Embedding Loss: 1.7058
# Valid MAE: 1.3934 | Valid Accuracy: 60.7477% | Valid Recall: 58.2090%
#
# Epoch [111/200]
# Train Loss: 2.3527 | Regression Loss: 0.6433 | Embedding Loss: 1.7094
# Valid MAE: 1.3996 | Valid Accuracy: 60.7477% | Valid Recall: 58.2090%
#
# Epoch [112/200]
# Train Loss: 2.3424 | Regression Loss: 0.6345 | Embedding Loss: 1.7079
# Valid MAE: 1.3818 | Valid Accuracy: 65.8879% | Valid Recall: 64.1791%
#
# Epoch [113/200]
# Train Loss: 2.3217 | Regression Loss: 0.6160 | Embedding Loss: 1.7057
# Valid MAE: 1.3923 | Valid Accuracy: 61.6822% | Valid Recall: 59.2040%
#
# Epoch [114/200]
# Train Loss: 2.3577 | Regression Loss: 0.6566 | Embedding Loss: 1.7011
# Valid MAE: 1.3868 | Valid Accuracy: 61.2150% | Valid Recall: 59.2040%
#
# Epoch [115/200]
# Train Loss: 2.3510 | Regression Loss: 0.6318 | Embedding Loss: 1.7192
# Valid MAE: 1.3842 | Valid Accuracy: 62.1495% | Valid Recall: 60.1990%
#
# Epoch [116/200]
# Train Loss: 2.3295 | Regression Loss: 0.6147 | Embedding Loss: 1.7147
# Valid MAE: 1.3918 | Valid Accuracy: 61.2150% | Valid Recall: 58.7065%
#
# Epoch [117/200]
# Train Loss: 2.3304 | Regression Loss: 0.6269 | Embedding Loss: 1.7035
# Valid MAE: 1.3827 | Valid Accuracy: 64.4860% | Valid Recall: 62.6866%
#
# Epoch [118/200]
# Train Loss: 2.3338 | Regression Loss: 0.6219 | Embedding Loss: 1.7119
# Valid MAE: 1.3862 | Valid Accuracy: 61.6822% | Valid Recall: 59.7015%
#
# Epoch [119/200]
# Train Loss: 2.3125 | Regression Loss: 0.6127 | Embedding Loss: 1.6998
# Valid MAE: 1.3874 | Valid Accuracy: 61.6822% | Valid Recall: 59.7015%
#
# Epoch [120/200]
# Train Loss: 2.3428 | Regression Loss: 0.6341 | Embedding Loss: 1.7087
# Valid MAE: 1.3803 | Valid Accuracy: 65.4206% | Valid Recall: 63.6816%
# Saving Best
#
# Epoch [121/200]
# Train Loss: 2.3168 | Regression Loss: 0.6143 | Embedding Loss: 1.7025
# Valid MAE: 1.3864 | Valid Accuracy: 61.6822% | Valid Recall: 59.7015%
#
# Epoch [122/200]
# Train Loss: 2.3253 | Regression Loss: 0.6189 | Embedding Loss: 1.7064
# Valid MAE: 1.3886 | Valid Accuracy: 60.2804% | Valid Recall: 58.2090%
#
# Epoch [123/200]
# Train Loss: 2.3626 | Regression Loss: 0.6519 | Embedding Loss: 1.7107
# Valid MAE: 1.3881 | Valid Accuracy: 61.2150% | Valid Recall: 59.2040%
#
# Epoch [124/200]
# Train Loss: 2.3334 | Regression Loss: 0.6213 | Embedding Loss: 1.7121
# Valid MAE: 1.3857 | Valid Accuracy: 62.1495% | Valid Recall: 60.1990%
#
# Epoch [125/200]
# Train Loss: 2.3326 | Regression Loss: 0.6184 | Embedding Loss: 1.7142
# Valid MAE: 1.3730 | Valid Accuracy: 68.6916% | Valid Recall: 67.1642%
# Saving Best
#
# Epoch [126/200]
# Train Loss: 2.3055 | Regression Loss: 0.6059 | Embedding Loss: 1.6996
# Valid MAE: 1.3891 | Valid Accuracy: 60.7477% | Valid Recall: 58.7065%
#
# Epoch [127/200]
# Train Loss: 2.3721 | Regression Loss: 0.6481 | Embedding Loss: 1.7241
# Valid MAE: 1.3832 | Valid Accuracy: 62.6168% | Valid Recall: 60.6965%
#
# Epoch [128/200]
# Train Loss: 2.2979 | Regression Loss: 0.5922 | Embedding Loss: 1.7057
# Valid MAE: 1.3805 | Valid Accuracy: 64.0187% | Valid Recall: 62.1891%
#
# Epoch [129/200]
# Train Loss: 2.3213 | Regression Loss: 0.6191 | Embedding Loss: 1.7022
# Valid MAE: 1.3841 | Valid Accuracy: 62.6168% | Valid Recall: 60.6965%
#
# Epoch [130/200]
# Train Loss: 2.2929 | Regression Loss: 0.5923 | Embedding Loss: 1.7006
# Valid MAE: 1.3850 | Valid Accuracy: 63.0841% | Valid Recall: 61.1940%
#
# Epoch [131/200]
# Train Loss: 2.2965 | Regression Loss: 0.5941 | Embedding Loss: 1.7024
# Valid MAE: 1.3823 | Valid Accuracy: 62.6168% | Valid Recall: 60.6965%
#
# Epoch [132/200]
# Train Loss: 2.2879 | Regression Loss: 0.5887 | Embedding Loss: 1.6992
# Valid MAE: 1.3822 | Valid Accuracy: 63.0841% | Valid Recall: 61.1940%
#
# Epoch [133/200]
# Train Loss: 2.2926 | Regression Loss: 0.5790 | Embedding Loss: 1.7136
# Valid MAE: 1.3916 | Valid Accuracy: 60.2804% | Valid Recall: 58.2090%
#
# Epoch [134/200]
# Train Loss: 2.3146 | Regression Loss: 0.5959 | Embedding Loss: 1.7187
# Valid MAE: 1.3883 | Valid Accuracy: 61.2150% | Valid Recall: 59.2040%
#
# Epoch [135/200]
# Train Loss: 2.2697 | Regression Loss: 0.5683 | Embedding Loss: 1.7014
# Valid MAE: 1.3838 | Valid Accuracy: 63.5514% | Valid Recall: 61.6915%
#
# Epoch [136/200]
# Train Loss: 2.2946 | Regression Loss: 0.5851 | Embedding Loss: 1.7095
# Valid MAE: 1.3888 | Valid Accuracy: 63.0841% | Valid Recall: 61.1940%
#
# Epoch [137/200]
# Train Loss: 2.3061 | Regression Loss: 0.5965 | Embedding Loss: 1.7096
# Valid MAE: 1.3807 | Valid Accuracy: 65.4206% | Valid Recall: 63.6816%
#
# Epoch [138/200]
# Train Loss: 2.2738 | Regression Loss: 0.5716 | Embedding Loss: 1.7023
# Valid MAE: 1.3807 | Valid Accuracy: 65.4206% | Valid Recall: 63.6816%
#
# Epoch [139/200]
# Train Loss: 2.2904 | Regression Loss: 0.5815 | Embedding Loss: 1.7089
# Valid MAE: 1.3942 | Valid Accuracy: 60.2804% | Valid Recall: 58.2090%
#
# Epoch [140/200]
# Train Loss: 2.3456 | Regression Loss: 0.6397 | Embedding Loss: 1.7059
# Valid MAE: 1.3905 | Valid Accuracy: 62.6168% | Valid Recall: 60.1990%
#
# Epoch [141/200]
# Train Loss: 2.3534 | Regression Loss: 0.6282 | Embedding Loss: 1.7253
# Valid MAE: 1.3818 | Valid Accuracy: 64.0187% | Valid Recall: 62.1891%
#
# Epoch [142/200]
# Train Loss: 2.3002 | Regression Loss: 0.5977 | Embedding Loss: 1.7025
# Valid MAE: 1.3884 | Valid Accuracy: 62.6168% | Valid Recall: 60.6965%
#
# Epoch [143/200]
# Train Loss: 2.3087 | Regression Loss: 0.5971 | Embedding Loss: 1.7115
# Valid MAE: 1.3860 | Valid Accuracy: 64.0187% | Valid Recall: 62.1891%
#
# Epoch [144/200]
# Train Loss: 2.2993 | Regression Loss: 0.5863 | Embedding Loss: 1.7130
# Valid MAE: 1.3919 | Valid Accuracy: 60.7477% | Valid Recall: 58.7065%
#
# Epoch [145/200]
# Train Loss: 2.3036 | Regression Loss: 0.5929 | Embedding Loss: 1.7107
# Valid MAE: 1.3875 | Valid Accuracy: 62.6168% | Valid Recall: 60.6965%
#
# Epoch [146/200]
# Train Loss: 2.3044 | Regression Loss: 0.5990 | Embedding Loss: 1.7054
# Valid MAE: 1.3806 | Valid Accuracy: 63.5514% | Valid Recall: 61.6915%
#
# Epoch [147/200]
# Train Loss: 2.2977 | Regression Loss: 0.5754 | Embedding Loss: 1.7223
# Valid MAE: 1.3852 | Valid Accuracy: 63.0841% | Valid Recall: 61.1940%
#
# Epoch [148/200]
# Train Loss: 2.2707 | Regression Loss: 0.5694 | Embedding Loss: 1.7013
# Valid MAE: 1.3834 | Valid Accuracy: 63.5514% | Valid Recall: 61.6915%
#
# Epoch [149/200]
# Train Loss: 2.2742 | Regression Loss: 0.5643 | Embedding Loss: 1.7099
# Valid MAE: 1.3809 | Valid Accuracy: 63.5514% | Valid Recall: 61.6915%
#
# Epoch [150/200]
# Train Loss: 2.2674 | Regression Loss: 0.5584 | Embedding Loss: 1.7090
# Valid MAE: 1.3867 | Valid Accuracy: 61.6822% | Valid Recall: 59.7015%
#
# Epoch [151/200]
# Train Loss: 2.3213 | Regression Loss: 0.6098 | Embedding Loss: 1.7115
# Valid MAE: 1.3760 | Valid Accuracy: 67.7570% | Valid Recall: 66.6667%
#
# Epoch [152/200]
# Train Loss: 2.2917 | Regression Loss: 0.5845 | Embedding Loss: 1.7072
# Valid MAE: 1.3825 | Valid Accuracy: 63.5514% | Valid Recall: 61.6915%
#
# Epoch [153/200]
# Train Loss: 2.2848 | Regression Loss: 0.5751 | Embedding Loss: 1.7097
# Valid MAE: 1.3874 | Valid Accuracy: 62.6168% | Valid Recall: 60.6965%
#
# Epoch [154/200]
# Train Loss: 2.2776 | Regression Loss: 0.5760 | Embedding Loss: 1.7016
# Valid MAE: 1.3836 | Valid Accuracy: 63.5514% | Valid Recall: 61.6915%
#
# Epoch [155/200]
# Train Loss: 2.2802 | Regression Loss: 0.5755 | Embedding Loss: 1.7047
# Valid MAE: 1.3858 | Valid Accuracy: 62.6168% | Valid Recall: 60.6965%
#
# Epoch [156/200]
# Train Loss: 2.2836 | Regression Loss: 0.5692 | Embedding Loss: 1.7143
# Valid MAE: 1.3897 | Valid Accuracy: 61.2150% | Valid Recall: 59.2040%
#
# Epoch [157/200]
# Train Loss: 2.2415 | Regression Loss: 0.5374 | Embedding Loss: 1.7041
# Valid MAE: 1.3791 | Valid Accuracy: 64.4860% | Valid Recall: 62.6866%
#
# Epoch [158/200]
# Train Loss: 2.2660 | Regression Loss: 0.5500 | Embedding Loss: 1.7160
# Valid MAE: 1.3814 | Valid Accuracy: 64.0187% | Valid Recall: 62.1891%
#
# Epoch [159/200]
# Train Loss: 2.2568 | Regression Loss: 0.5416 | Embedding Loss: 1.7152
# Valid MAE: 1.3795 | Valid Accuracy: 64.0187% | Valid Recall: 62.1891%
#
# Epoch [160/200]
# Train Loss: 2.2390 | Regression Loss: 0.5362 | Embedding Loss: 1.7029
# Valid MAE: 1.3813 | Valid Accuracy: 64.4860% | Valid Recall: 62.6866%
#
# Epoch [161/200]
# Train Loss: 2.2485 | Regression Loss: 0.5416 | Embedding Loss: 1.7069
# Valid MAE: 1.3865 | Valid Accuracy: 62.6168% | Valid Recall: 60.6965%
#
# Epoch [162/200]
# Train Loss: 2.2359 | Regression Loss: 0.5362 | Embedding Loss: 1.6998
# Valid MAE: 1.3851 | Valid Accuracy: 63.5514% | Valid Recall: 61.6915%
#
# Epoch [163/200]
# Train Loss: 2.2700 | Regression Loss: 0.5682 | Embedding Loss: 1.7018
# Valid MAE: 1.3740 | Valid Accuracy: 69.1589% | Valid Recall: 68.1592%
#
# Epoch [164/200]
# Train Loss: 2.3206 | Regression Loss: 0.5977 | Embedding Loss: 1.7229
# Valid MAE: 1.3853 | Valid Accuracy: 62.1495% | Valid Recall: 60.1990%
#
# Epoch [165/200]
# Train Loss: 2.2873 | Regression Loss: 0.5736 | Embedding Loss: 1.7137
# Valid MAE: 1.3773 | Valid Accuracy: 67.7570% | Valid Recall: 66.1692%
#
# Epoch [166/200]
# Train Loss: 2.2340 | Regression Loss: 0.5303 | Embedding Loss: 1.7038
# Valid MAE: 1.3842 | Valid Accuracy: 63.5514% | Valid Recall: 61.6915%
#
# Epoch [167/200]
# Train Loss: 2.2701 | Regression Loss: 0.5698 | Embedding Loss: 1.7003
# Valid MAE: 1.3768 | Valid Accuracy: 65.4206% | Valid Recall: 63.6816%
#
# Epoch [168/200]
# Train Loss: 2.2700 | Regression Loss: 0.5712 | Embedding Loss: 1.6989
# Valid MAE: 1.3877 | Valid Accuracy: 62.6168% | Valid Recall: 60.6965%
#
# Epoch [169/200]
# Train Loss: 2.2735 | Regression Loss: 0.5541 | Embedding Loss: 1.7194
# Valid MAE: 1.3871 | Valid Accuracy: 62.6168% | Valid Recall: 60.6965%
#
# Epoch [170/200]
# Train Loss: 2.2665 | Regression Loss: 0.5672 | Embedding Loss: 1.6993
# Valid MAE: 1.3870 | Valid Accuracy: 63.0841% | Valid Recall: 61.1940%
#
# Epoch [171/200]
# Train Loss: 2.2246 | Regression Loss: 0.5225 | Embedding Loss: 1.7021
# Valid MAE: 1.3822 | Valid Accuracy: 63.5514% | Valid Recall: 61.6915%
#
# Epoch [172/200]
# Train Loss: 2.2493 | Regression Loss: 0.5378 | Embedding Loss: 1.7115
# Valid MAE: 1.3658 | Valid Accuracy: 71.4953% | Valid Recall: 70.6468%
# Saving Best
#
# Epoch [173/200]
# Train Loss: 2.2657 | Regression Loss: 0.5500 | Embedding Loss: 1.7157
# Valid MAE: 1.3817 | Valid Accuracy: 64.0187% | Valid Recall: 62.1891%
#
# Epoch [174/200]
# Train Loss: 2.2303 | Regression Loss: 0.5352 | Embedding Loss: 1.6952
# Valid MAE: 1.3819 | Valid Accuracy: 63.0841% | Valid Recall: 61.1940%
#
# Epoch [175/200]
# Train Loss: 2.2270 | Regression Loss: 0.5210 | Embedding Loss: 1.7060
# Valid MAE: 1.3767 | Valid Accuracy: 65.4206% | Valid Recall: 63.6816%
#
# Epoch [176/200]
# Train Loss: 2.2412 | Regression Loss: 0.5316 | Embedding Loss: 1.7096
# Valid MAE: 1.3811 | Valid Accuracy: 63.5514% | Valid Recall: 61.6915%
#
# Epoch [177/200]
# Train Loss: 2.2414 | Regression Loss: 0.5386 | Embedding Loss: 1.7027
# Valid MAE: 1.3812 | Valid Accuracy: 63.5514% | Valid Recall: 61.6915%
#
# Epoch [178/200]
# Train Loss: 2.2365 | Regression Loss: 0.5221 | Embedding Loss: 1.7144
# Valid MAE: 1.3839 | Valid Accuracy: 64.4860% | Valid Recall: 62.6866%
#
# Epoch [179/200]
# Train Loss: 2.2415 | Regression Loss: 0.5394 | Embedding Loss: 1.7021
# Valid MAE: 1.3786 | Valid Accuracy: 63.5514% | Valid Recall: 61.6915%
#
# Epoch [180/200]
# Train Loss: 2.2327 | Regression Loss: 0.5395 | Embedding Loss: 1.6932
# Valid MAE: 1.3776 | Valid Accuracy: 64.4860% | Valid Recall: 62.6866%
#
# Epoch [181/200]
# Train Loss: 2.2379 | Regression Loss: 0.5307 | Embedding Loss: 1.7072
# Valid MAE: 1.3826 | Valid Accuracy: 63.5514% | Valid Recall: 61.6915%
#
# Epoch [182/200]
# Train Loss: 2.2372 | Regression Loss: 0.5220 | Embedding Loss: 1.7152
# Valid MAE: 1.3731 | Valid Accuracy: 67.2897% | Valid Recall: 66.1692%
#
# Epoch [183/200]
# Train Loss: 2.2435 | Regression Loss: 0.5412 | Embedding Loss: 1.7022
# Valid MAE: 1.3784 | Valid Accuracy: 63.5514% | Valid Recall: 61.6915%
#
# Epoch [184/200]
# Train Loss: 2.2231 | Regression Loss: 0.5163 | Embedding Loss: 1.7068
# Valid MAE: 1.3827 | Valid Accuracy: 64.0187% | Valid Recall: 62.1891%
#
# Epoch [185/200]
# Train Loss: 2.2372 | Regression Loss: 0.5301 | Embedding Loss: 1.7071
# Valid MAE: 1.3773 | Valid Accuracy: 65.4206% | Valid Recall: 63.6816%
#
# Epoch [186/200]
# Train Loss: 2.2169 | Regression Loss: 0.5130 | Embedding Loss: 1.7039
# Valid MAE: 1.3782 | Valid Accuracy: 64.9533% | Valid Recall: 63.1841%
#
# Epoch [187/200]
# Train Loss: 2.2203 | Regression Loss: 0.5127 | Embedding Loss: 1.7077
# Valid MAE: 1.3787 | Valid Accuracy: 64.4860% | Valid Recall: 62.6866%
#
# Epoch [188/200]
# Train Loss: 2.2130 | Regression Loss: 0.5081 | Embedding Loss: 1.7050
# Valid MAE: 1.3815 | Valid Accuracy: 64.0187% | Valid Recall: 62.1891%
#
# Epoch [189/200]
# Train Loss: 2.2047 | Regression Loss: 0.5034 | Embedding Loss: 1.7013
# Valid MAE: 1.3790 | Valid Accuracy: 64.4860% | Valid Recall: 62.6866%
#
# Epoch [190/200]
# Train Loss: 2.2194 | Regression Loss: 0.5111 | Embedding Loss: 1.7083
# Valid MAE: 1.3813 | Valid Accuracy: 64.0187% | Valid Recall: 62.1891%
#
# Epoch [191/200]
# Train Loss: 2.2355 | Regression Loss: 0.5346 | Embedding Loss: 1.7009
# Valid MAE: 1.3700 | Valid Accuracy: 67.2897% | Valid Recall: 66.1692%
#
# Epoch [192/200]
# Train Loss: 2.2641 | Regression Loss: 0.5406 | Embedding Loss: 1.7236
# Valid MAE: 1.3758 | Valid Accuracy: 64.4860% | Valid Recall: 62.6866%
#
# Epoch [193/200]
# Train Loss: 2.2592 | Regression Loss: 0.5280 | Embedding Loss: 1.7312
# Valid MAE: 1.3813 | Valid Accuracy: 64.0187% | Valid Recall: 62.1891%
#
# Epoch [194/200]
# Train Loss: 2.2342 | Regression Loss: 0.5092 | Embedding Loss: 1.7250
# Valid MAE: 1.3736 | Valid Accuracy: 65.4206% | Valid Recall: 64.1791%
#
# Epoch [195/200]
# Train Loss: 2.2486 | Regression Loss: 0.5239 | Embedding Loss: 1.7246
# Valid MAE: 1.3723 | Valid Accuracy: 65.8879% | Valid Recall: 64.6766%
#
# Epoch [196/200]
# Train Loss: 2.2202 | Regression Loss: 0.5204 | Embedding Loss: 1.6998
# Valid MAE: 1.3676 | Valid Accuracy: 69.6262% | Valid Recall: 69.1542%
#
# Epoch [197/200]
# Train Loss: 2.2370 | Regression Loss: 0.5240 | Embedding Loss: 1.7130
# Valid MAE: 1.3752 | Valid Accuracy: 66.3551% | Valid Recall: 64.6766%
#
# Epoch [198/200]
# Train Loss: 2.2059 | Regression Loss: 0.4977 | Embedding Loss: 1.7082
# Valid MAE: 1.3678 | Valid Accuracy: 69.6262% | Valid Recall: 68.6567%
#
# Epoch [199/200]
# Train Loss: 2.2116 | Regression Loss: 0.5032 | Embedding Loss: 1.7084
# Valid MAE: 1.3794 | Valid Accuracy: 64.4860% | Valid Recall: 62.6866%
#
# Epoch [200/200]
# Train Loss: 2.1993 | Regression Loss: 0.4989 | Embedding Loss: 1.7004
# Valid MAE: 1.3805 | Valid Accuracy: 64.0187% | Valid Recall: 62.1891%
#
# Training Time: 20m53s
# Training Params: 198809

# %%
plt.plot(train_losses, label='Train Loss')
plt.plot(valid_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.title('Loss vs. No. of epochs')
# Out:
# Text(0.5, 1.0, 'Loss vs. No. of epochs')

# %%
save_results(train_losses, valid_losses, f'/content/{OUTPUT_MODEL_FILE_NAME}.pkl')

# %% [markdown]
# ## Testing

# %%
model = torch.load(f'/content/{OUTPUT_MODEL_FILE_NAME}.pt').to(device)

test(model, test_data)
# Out:
# <ipython-input-25-b05a4276e506>:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f'/content/{OUTPUT_MODEL_FILE_NAME}.pt').to(device)
# Test MAE: 1.3534 | Test Accuracy: 72.4490% | Test Recall: 72.4085%
# Inference Time: 580ms
# Inference Params: 198809
